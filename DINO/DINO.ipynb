# %% [markdown]
# # Homework - DINO
# ### Sharif University - Deep Learning Course - Spring 2024
#
# *Instructor:  Dr. Soleymani*
#
# ---
#
# *Full Name:* Amirhossein Akbari
#
# *SID:* 400104737
#
# ---

# %% [markdown]
# In this homework we will learn to use the DINO model.
#
# In this homework you need to complete the notebook and run all the cells.
# We have specified the parts to be completed with `TODO` tags inside the code blocks.
#
# **NOTES**:
# * It is important that you read all the code and text blocks carefully, even if you think you are excited to jump into completing the missing codes.
# * This notebook is tested with *Google Colab* and *Kaggle* free runtimes and you can used them for testing your code.
# * Ensure all cells are executable and perform their intended functions
# * You can ask your questions on [Quera Class](https://quera.org/course/16605/)
# * Write clear, commented code when necessary.

# %% [markdown]
# # Introduction

# %% [markdown]
# Listen up, folks! You know how they say dinosaurs are extinct? Well, they lied to us. The DINO model is proof that these ancient beasts are still roaming the earth, but this time, they're here to help us with feature extraction and downstream tasks. Imagine a T-Rex with a fancy deep learning algorithm strapped to its back, stomping around and making sense of all the data in its path.
#
# But wait, it gets better! This dino doesn't just extract features; it does it in a self-supervised manner, which means it's like a kid who learned to tie its own shoelaces without any help from its parents (or, in this case, labeled data). And once it's done extracting those juicy features, it's ready to tackle any downstream task you throw its way, whether it's image classification, object detection, or even predicting the next hot dinosaur-themed movie.

# %% [markdown]
# In this homework assignment, we will be utilizing the DINO model to extract meaningful visual features from satellite imagery data. The self-supervised DINO model has proven to be an effective tool for extracting rich representations from visual data without the need for labeled examples during pre-training.
#
# Specifically, we will leverage the DINO model's capabilities to extract visual features from satellite images. These extracted features will then be used to train a classifier on top of the DINO backbone. The goal of this classifier is to predict whether a given satellite image contains solar panels or not.
#
# Moving on to the second part of the assignment, we will explore the transformer attention maps produced by the DINO model. By analyzing these attention maps, we aim to estimate the size of the solar panels present in the positive examples from the dataset.
#
# While not as exhilarating as envisioning a dinosaur with deep learning capabilities, this assignment presents an opportunity to gain hands-on experience with a state-of-the-art self-supervised model and its applications in computer vision tasks. I'm sure you'll find the process insightful and rewarding.

# %% [markdown]
# # Installations and imports

# %% [markdown]
# As usual, imports are our first step.

# %%
# !pip install einops
# Out:
# Collecting einops
#   Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.8.0

# %%
# !pip install rasterio
# Out:
# Collecting rasterio
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 56.4 MB/s eta 0:00:00
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.6.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.25.2)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio) (67.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio) (3.1.2)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.3.10 snuggs-1.4.7

# %%
import glob
import torch
import rasterio
import numpy as np
import einops as eo
import random as rnd
import torch.nn as nn
from PIL import Image
from pathlib import Path
import matplotlib.pyplot as plt
import torch.nn.functional as F
from matplotlib.colors import Normalize
from torch.utils.data import Dataset, DataLoader, random_split
import shutil
import os

# %% [markdown]
# # Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install gdown
import gdown

# Move the dataset to this colab session.
# We suggest you add a shortcut from the given file to your own google drive account and then copy the file from that shortcut to here.

# ======================= Your Code =======================
file_id = '1OYeyT4-Nj1KGa78dNgrPI0sUsbF3QEEn'
download_path = '/content/dataset.zip'
gdown.download(id=file_id, output=download_path, quiet=False)
local_path = '/content/dataset'
# !unzip /content/dataset.zip -d /content/dataset
# ======================= Your Code =======================
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.1.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.15.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.6.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From (original): https://drive.google.com/uc?id=1OYeyT4-Nj1KGa78dNgrPI0sUsbF3QEEn
# From (redirected): https://drive.google.com/uc?id=1OYeyT4-Nj1KGa78dNgrPI0sUsbF3QEEn&confirm=t&uuid=b7113c68-5c02-4ebe-b8c3-ada8a6ce7d68
# To: /content/dataset.zip
# 100%|██████████| 1.92G/1.92G [00:26<00:00, 73.4MB/s]
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/uk20K_v2/111412-P.tif
#   inflating: /content/dataset/uk20K_v2/3374-N.tif
#   inflating: /content/dataset/uk20K_v2/486881-N.tif
#   inflating: /content/dataset/uk20K_v2/6129-P.tif
#   inflating: /content/dataset/uk20K_v2/92423-P.tif
#   inflating: /content/dataset/uk20K_v2/709543-N.tif
#   inflating: /content/dataset/uk20K_v2/54256-P.tif
#   inflating: /content/dataset/uk20K_v2/111122-N.tif
#   inflating: /content/dataset/uk20K_v2/697872-N.tif
#   inflating: /content/dataset/uk20K_v2/269296-N.tif
#   inflating: /content/dataset/uk20K_v2/161532-N.tif
#   inflating: /content/dataset/uk20K_v2/94179-P.tif
#   inflating: /content/dataset/uk20K_v2/600055-N.tif
#   inflating: /content/dataset/uk20K_v2/105520-P.tif
#   inflating: /content/dataset/uk20K_v2/578873-N.tif
#   inflating: /content/dataset/uk20K_v2/59564-N.tif
#   inflating: /content/dataset/uk20K_v2/110893-N.tif
#   inflating: /content/dataset/uk20K_v2/71071-P.tif
#   inflating: /content/dataset/uk20K_v2/714753-N.tif
#   inflating: /content/dataset/uk20K_v2/37732-P.tif
#   inflating: /content/dataset/uk20K_v2/88134-P.tif
#   inflating: /content/dataset/uk20K_v2/315686-N.tif
#   inflating: /content/dataset/uk20K_v2/343921-N.tif
#   inflating: /content/dataset/uk20K_v2/125646-P.tif
#   inflating: /content/dataset/uk20K_v2/551801-N.tif
#   inflating: /content/dataset/uk20K_v2/86460-N.tif
#   inflating: /content/dataset/uk20K_v2/589775-N.tif
#   inflating: /content/dataset/uk20K_v2/144887-N.tif
#   inflating: /content/dataset/uk20K_v2/51165-P.tif
#   inflating: /content/dataset/uk20K_v2/95981-N.tif
#   inflating: /content/dataset/uk20K_v2/30920-P.tif
#   inflating: /content/dataset/uk20K_v2/157414-P.tif
#   inflating: /content/dataset/uk20K_v2/41855-P.tif
#   inflating: /content/dataset/uk20K_v2/122401-P.tif
#   inflating: /content/dataset/uk20K_v2/52607-N.tif
#   inflating: /content/dataset/uk20K_v2/30041-P.tif
#   inflating: /content/dataset/uk20K_v2/451451-N.tif
#   inflating: /content/dataset/uk20K_v2/100323-P.tif
#   inflating: /content/dataset/uk20K_v2/92519-P.tif
#   inflating: /content/dataset/uk20K_v2/306376-N.tif
#   inflating: /content/dataset/uk20K_v2/413934-N.tif
#   inflating: /content/dataset/uk20K_v2/721987-N.tif
#   inflating: /content/dataset/uk20K_v2/84370-N.tif
#   inflating: /content/dataset/uk20K_v2/137434-N.tif
#   inflating: /content/dataset/uk20K_v2/59755-P.tif
#   inflating: /content/dataset/uk20K_v2/45497-P.tif
#   inflating: /content/dataset/uk20K_v2/656100-N.tif
#   inflating: /content/dataset/uk20K_v2/677653-N.tif
#   inflating: /content/dataset/uk20K_v2/680671-N.tif
#   inflating: /content/dataset/uk20K_v2/123904-P.tif
#   inflating: /content/dataset/uk20K_v2/92815-N.tif
#   inflating: /content/dataset/uk20K_v2/488939-N.tif
#   inflating: /content/dataset/uk20K_v2/455787-N.tif
#   inflating: /content/dataset/uk20K_v2/604473-N.tif
#   inflating: /content/dataset/uk20K_v2/669695-N.tif
#   inflating: /content/dataset/uk20K_v2/588015-N.tif
#   inflating: /content/dataset/uk20K_v2/76795-P.tif
#   inflating: /content/dataset/uk20K_v2/532519-N.tif
#   inflating: /content/dataset/uk20K_v2/614800-N.tif
#   inflating: /content/dataset/uk20K_v2/49254-P.tif
#   inflating: /content/dataset/uk20K_v2/176997-P.tif
#   inflating: /content/dataset/uk20K_v2/84529-N.tif
#   inflating: /content/dataset/uk20K_v2/563700-N.tif
#   inflating: /content/dataset/uk20K_v2/175196-N.tif
#   inflating: /content/dataset/uk20K_v2/568680-N.tif
#   inflating: /content/dataset/uk20K_v2/27607-N.tif
#   inflating: /content/dataset/uk20K_v2/568988-N.tif
#   inflating: /content/dataset/uk20K_v2/150125-P.tif
#   inflating: /content/dataset/uk20K_v2/699680-N.tif
#   inflating: /content/dataset/uk20K_v2/457047-N.tif
#   inflating: /content/dataset/uk20K_v2/35051-P.tif
#   inflating: /content/dataset/uk20K_v2/721891-N.tif
#   inflating: /content/dataset/uk20K_v2/422998-N.tif
#   inflating: /content/dataset/uk20K_v2/679935-N.tif
#   inflating: /content/dataset/uk20K_v2/42075-P.tif
#   inflating: /content/dataset/uk20K_v2/337562-N.tif
#   inflating: /content/dataset/uk20K_v2/20225-N.tif
#   inflating: /content/dataset/uk20K_v2/392207-N.tif
#   inflating: /content/dataset/uk20K_v2/145826-P.tif
#   inflating: /content/dataset/uk20K_v2/260504-N.tif
#   inflating: /content/dataset/uk20K_v2/594400-N.tif
#   inflating: /content/dataset/uk20K_v2/156761-P.tif
#   inflating: /content/dataset/uk20K_v2/69415-P.tif
#   inflating: /content/dataset/uk20K_v2/117238-P.tif
#   inflating: /content/dataset/uk20K_v2/91035-P.tif
#   inflating: /content/dataset/uk20K_v2/150530-P.tif
#   inflating: /content/dataset/uk20K_v2/308929-N.tif
#   inflating: /content/dataset/uk20K_v2/120069-N.tif
#   inflating: /content/dataset/uk20K_v2/39740-P.tif
#   inflating: /content/dataset/uk20K_v2/537148-N.tif
#   inflating: /content/dataset/uk20K_v2/337067-N.tif
#   inflating: /content/dataset/uk20K_v2/45580-P.tif
#   inflating: /content/dataset/uk20K_v2/204611-N.tif
#   inflating: /content/dataset/uk20K_v2/82139-P.tif
#   inflating: /content/dataset/uk20K_v2/63732-P.tif
#   inflating: /content/dataset/uk20K_v2/25229-P.tif
#   inflating: /content/dataset/uk20K_v2/87111-P.tif
#   inflating: /content/dataset/uk20K_v2/160998-P.tif
#   inflating: /content/dataset/uk20K_v2/76598-P.tif
#   inflating: /content/dataset/uk20K_v2/536873-N.tif
#   inflating: /content/dataset/uk20K_v2/422565-N.tif
#   inflating: /content/dataset/uk20K_v2/146018-P.tif
#   inflating: /content/dataset/uk20K_v2/51451-P.tif
#   inflating: /content/dataset/uk20K_v2/165645-P.tif
#   inflating: /content/dataset/uk20K_v2/630061-N.tif
#   inflating: /content/dataset/uk20K_v2/156059-P.tif
#   inflating: /content/dataset/uk20K_v2/38646-P.tif
#   inflating: /content/dataset/uk20K_v2/66599-P.tif
#   inflating: /content/dataset/uk20K_v2/663408-N.tif
#   inflating: /content/dataset/uk20K_v2/148667-P.tif
#   inflating: /content/dataset/uk20K_v2/181851-P.tif
#   inflating: /content/dataset/uk20K_v2/568161-N.tif
#   inflating: /content/dataset/uk20K_v2/76256-P.tif
#   inflating: /content/dataset/uk20K_v2/156280-P.tif
#   inflating: /content/dataset/uk20K_v2/491270-N.tif
#   inflating: /content/dataset/uk20K_v2/628187-N.tif
#   inflating: /content/dataset/uk20K_v2/93085-P.tif
#   inflating: /content/dataset/uk20K_v2/189036-N.tif
#   inflating: /content/dataset/uk20K_v2/158729-P.tif
#   inflating: /content/dataset/uk20K_v2/8304-P.tif
#   inflating: /content/dataset/uk20K_v2/60013-P.tif
#   inflating: /content/dataset/uk20K_v2/136317-P.tif
#   inflating: /content/dataset/uk20K_v2/727000-N.tif
#   inflating: /content/dataset/uk20K_v2/325658-N.tif
#   inflating: /content/dataset/uk20K_v2/150138-P.tif
#   inflating: /content/dataset/uk20K_v2/624215-N.tif
#   inflating: /content/dataset/uk20K_v2/592371-N.tif
#   inflating: /content/dataset/uk20K_v2/13413-P.tif
#   inflating: /content/dataset/uk20K_v2/471897-N.tif
#   inflating: /content/dataset/uk20K_v2/88310-N.tif
#   inflating: /content/dataset/uk20K_v2/690943-N.tif
#   inflating: /content/dataset/uk20K_v2/49107-P.tif
#   inflating: /content/dataset/uk20K_v2/518333-N.tif
#   inflating: /content/dataset/uk20K_v2/160979-P.tif
#   inflating: /content/dataset/uk20K_v2/129048-P.tif
#   inflating: /content/dataset/uk20K_v2/241298-N.tif
#   inflating: /content/dataset/uk20K_v2/93986-P.tif
#   inflating: /content/dataset/uk20K_v2/639950-N.tif
#   inflating: /content/dataset/uk20K_v2/64721-P.tif
#   inflating: /content/dataset/uk20K_v2/117817-P.tif
#   inflating: /content/dataset/uk20K_v2/5233-N.tif
#   inflating: /content/dataset/uk20K_v2/575486-N.tif
#   inflating: /content/dataset/uk20K_v2/665849-N.tif
#   inflating: /content/dataset/uk20K_v2/128779-P.tif
#   inflating: /content/dataset/uk20K_v2/21076-P.tif
#   inflating: /content/dataset/uk20K_v2/520257-N.tif
#   inflating: /content/dataset/uk20K_v2/31697-P.tif
#   inflating: /content/dataset/uk20K_v2/75909-P.tif
#   inflating: /content/dataset/uk20K_v2/331220-N.tif
#   inflating: /content/dataset/uk20K_v2/53512-N.tif
#   inflating: /content/dataset/uk20K_v2/135473-P.tif
#   inflating: /content/dataset/uk20K_v2/6270-P.tif
#   inflating: /content/dataset/uk20K_v2/501729-N.tif
#   inflating: /content/dataset/uk20K_v2/34166-P.tif
#   inflating: /content/dataset/uk20K_v2/234318-N.tif
#   inflating: /content/dataset/uk20K_v2/595271-N.tif
#   inflating: /content/dataset/uk20K_v2/56660-N.tif
#   inflating: /content/dataset/uk20K_v2/176838-P.tif
#   inflating: /content/dataset/uk20K_v2/37073-P.tif
#   inflating: /content/dataset/uk20K_v2/20433-P.tif
#   inflating: /content/dataset/uk20K_v2/75385-P.tif
#   inflating: /content/dataset/uk20K_v2/667225-N.tif
#   inflating: /content/dataset/uk20K_v2/112514-N.tif
#   inflating: /content/dataset/uk20K_v2/54697-N.tif
#   inflating: /content/dataset/uk20K_v2/254158-N.tif
#   inflating: /content/dataset/uk20K_v2/561325-N.tif
#   inflating: /content/dataset/uk20K_v2/86586-P.tif
#   inflating: /content/dataset/uk20K_v2/7577-P.tif
#   inflating: /content/dataset/uk20K_v2/255763-N.tif
#   inflating: /content/dataset/uk20K_v2/106247-P.tif
#   inflating: /content/dataset/uk20K_v2/28767-P.tif
#   inflating: /content/dataset/uk20K_v2/182025-N.tif
#   inflating: /content/dataset/uk20K_v2/60175-P.tif
#   inflating: /content/dataset/uk20K_v2/418814-N.tif
#   inflating: /content/dataset/uk20K_v2/114492-P.tif
#   inflating: /content/dataset/uk20K_v2/294557-N.tif
#   inflating: /content/dataset/uk20K_v2/179530-P.tif
#   inflating: /content/dataset/uk20K_v2/117328-N.tif
#   inflating: /content/dataset/uk20K_v2/49120-P.tif
#   inflating: /content/dataset/uk20K_v2/76883-P.tif
#   inflating: /content/dataset/uk20K_v2/546042-N.tif
#   inflating: /content/dataset/uk20K_v2/245610-N.tif
#   inflating: /content/dataset/uk20K_v2/6278-P.tif
#   inflating: /content/dataset/uk20K_v2/509490-N.tif
#   inflating: /content/dataset/uk20K_v2/282581-N.tif
#   inflating: /content/dataset/uk20K_v2/57794-P.tif
#   inflating: /content/dataset/uk20K_v2/642499-N.tif
#   inflating: /content/dataset/uk20K_v2/496666-N.tif
#   inflating: /content/dataset/uk20K_v2/654082-N.tif
#   inflating: /content/dataset/uk20K_v2/165322-P.tif
#   inflating: /content/dataset/uk20K_v2/12462-P.tif
#   inflating: /content/dataset/uk20K_v2/546704-N.tif
#   inflating: /content/dataset/uk20K_v2/426281-N.tif
#   inflating: /content/dataset/uk20K_v2/184286-N.tif
#   inflating: /content/dataset/uk20K_v2/160705-P.tif
#   inflating: /content/dataset/uk20K_v2/134713-N.tif
#   inflating: /content/dataset/uk20K_v2/190941-N.tif
#   inflating: /content/dataset/uk20K_v2/677094-N.tif
#   inflating: /content/dataset/uk20K_v2/15340-N.tif
#   inflating: /content/dataset/uk20K_v2/144011-P.tif
#   inflating: /content/dataset/uk20K_v2/112470-P.tif
#   inflating: /content/dataset/uk20K_v2/41888-P.tif
#   inflating: /content/dataset/uk20K_v2/90499-P.tif
#   inflating: /content/dataset/uk20K_v2/184603-N.tif
#   inflating: /content/dataset/uk20K_v2/159251-P.tif
#   inflating: /content/dataset/uk20K_v2/179720-N.tif
#   inflating: /content/dataset/uk20K_v2/181100-P.tif
#   inflating: /content/dataset/uk20K_v2/19174-P.tif
#   inflating: /content/dataset/uk20K_v2/428770-N.tif
#   inflating: /content/dataset/uk20K_v2/103188-P.tif
#   inflating: /content/dataset/uk20K_v2/288515-N.tif
#   inflating: /content/dataset/uk20K_v2/602065-N.tif
#   inflating: /content/dataset/uk20K_v2/46649-P.tif
#   inflating: /content/dataset/uk20K_v2/39421-P.tif
#   inflating: /content/dataset/uk20K_v2/699689-N.tif
#   inflating: /content/dataset/uk20K_v2/130487-P.tif
#   inflating: /content/dataset/uk20K_v2/12599-P.tif
#   inflating: /content/dataset/uk20K_v2/160247-P.tif
#   inflating: /content/dataset/uk20K_v2/64876-P.tif
#   inflating: /content/dataset/uk20K_v2/153774-N.tif
#   inflating: /content/dataset/uk20K_v2/86121-N.tif
#   inflating: /content/dataset/uk20K_v2/590110-N.tif
#   inflating: /content/dataset/uk20K_v2/6652-P.tif
#   inflating: /content/dataset/uk20K_v2/82538-N.tif
#   inflating: /content/dataset/uk20K_v2/538718-N.tif
#   inflating: /content/dataset/uk20K_v2/104059-P.tif
#   inflating: /content/dataset/uk20K_v2/32908-P.tif
#   inflating: /content/dataset/uk20K_v2/141108-N.tif
#   inflating: /content/dataset/uk20K_v2/174790-P.tif
#   inflating: /content/dataset/uk20K_v2/681344-N.tif
#   inflating: /content/dataset/uk20K_v2/669499-N.tif
#   inflating: /content/dataset/uk20K_v2/130414-N.tif
#   inflating: /content/dataset/uk20K_v2/646626-N.tif
#   inflating: /content/dataset/uk20K_v2/432906-N.tif
#   inflating: /content/dataset/uk20K_v2/78007-P.tif
#   inflating: /content/dataset/uk20K_v2/493029-N.tif
#   inflating: /content/dataset/uk20K_v2/399713-N.tif
#   inflating: /content/dataset/uk20K_v2/21265-P.tif
#   inflating: /content/dataset/uk20K_v2/72308-P.tif
#   inflating: /content/dataset/uk20K_v2/48297-P.tif
#   inflating: /content/dataset/uk20K_v2/25116-P.tif
#   inflating: /content/dataset/uk20K_v2/146505-P.tif
#   inflating: /content/dataset/uk20K_v2/158336-P.tif
#   inflating: /content/dataset/uk20K_v2/614053-N.tif
#   inflating: /content/dataset/uk20K_v2/142392-P.tif
#   inflating: /content/dataset/uk20K_v2/107086-P.tif
#   inflating: /content/dataset/uk20K_v2/149865-P.tif
#   inflating: /content/dataset/uk20K_v2/437017-N.tif
#   inflating: /content/dataset/uk20K_v2/61286-P.tif
#   inflating: /content/dataset/uk20K_v2/166829-N.tif
#   inflating: /content/dataset/uk20K_v2/292786-N.tif
#   inflating: /content/dataset/uk20K_v2/158160-P.tif
#   inflating: /content/dataset/uk20K_v2/364315-N.tif
#   inflating: /content/dataset/uk20K_v2/117084-P.tif
#   inflating: /content/dataset/uk20K_v2/57597-P.tif
#   inflating: /content/dataset/uk20K_v2/440535-N.tif
#   inflating: /content/dataset/uk20K_v2/110889-P.tif
#   inflating: /content/dataset/uk20K_v2/51473-P.tif
#   inflating: /content/dataset/uk20K_v2/59171-P.tif
#   inflating: /content/dataset/uk20K_v2/155838-P.tif
#   inflating: /content/dataset/uk20K_v2/508921-N.tif
#   inflating: /content/dataset/uk20K_v2/93006-P.tif
#   inflating: /content/dataset/uk20K_v2/159349-P.tif
#   inflating: /content/dataset/uk20K_v2/91674-N.tif
#   inflating: /content/dataset/uk20K_v2/612107-N.tif
#   inflating: /content/dataset/uk20K_v2/378285-N.tif
#   inflating: /content/dataset/uk20K_v2/577468-N.tif
#   inflating: /content/dataset/uk20K_v2/507408-N.tif
#   inflating: /content/dataset/uk20K_v2/230715-N.tif
#   inflating: /content/dataset/uk20K_v2/154437-N.tif
#   inflating: /content/dataset/uk20K_v2/350422-N.tif
#   inflating: /content/dataset/uk20K_v2/80023-N.tif
#   inflating: /content/dataset/uk20K_v2/93379-P.tif
#   inflating: /content/dataset/uk20K_v2/510312-N.tif
#   inflating: /content/dataset/uk20K_v2/208838-N.tif
#   inflating: /content/dataset/uk20K_v2/170757-P.tif
#   inflating: /content/dataset/uk20K_v2/122712-P.tif
#   inflating: /content/dataset/uk20K_v2/77475-P.tif
#   inflating: /content/dataset/uk20K_v2/401032-N.tif
#   inflating: /content/dataset/uk20K_v2/271044-N.tif
#   inflating: /content/dataset/uk20K_v2/585966-N.tif
#   inflating: /content/dataset/uk20K_v2/62863-P.tif
#   inflating: /content/dataset/uk20K_v2/559543-N.tif
#   inflating: /content/dataset/uk20K_v2/401682-N.tif
#   inflating: /content/dataset/uk20K_v2/163058-N.tif
#   inflating: /content/dataset/uk20K_v2/9140-P.tif
#   inflating: /content/dataset/uk20K_v2/580840-N.tif
#   inflating: /content/dataset/uk20K_v2/171145-P.tif
#   inflating: /content/dataset/uk20K_v2/122116-N.tif
#   inflating: /content/dataset/uk20K_v2/630442-N.tif
#   inflating: /content/dataset/uk20K_v2/27369-P.tif
#   inflating: /content/dataset/uk20K_v2/438864-N.tif
#   inflating: /content/dataset/uk20K_v2/431893-N.tif
#   inflating: /content/dataset/uk20K_v2/91036-P.tif
#   inflating: /content/dataset/uk20K_v2/350136-N.tif
#   inflating: /content/dataset/uk20K_v2/151024-P.tif
#   inflating: /content/dataset/uk20K_v2/89990-P.tif
#   inflating: /content/dataset/uk20K_v2/150485-P.tif
#   inflating: /content/dataset/uk20K_v2/54868-P.tif
#   inflating: /content/dataset/uk20K_v2/405193-N.tif
#   inflating: /content/dataset/uk20K_v2/202907-N.tif
#   inflating: /content/dataset/uk20K_v2/516975-N.tif
#   inflating: /content/dataset/uk20K_v2/129377-P.tif
#   inflating: /content/dataset/uk20K_v2/682003-N.tif
#   inflating: /content/dataset/uk20K_v2/167506-P.tif
#   inflating: /content/dataset/uk20K_v2/171961-P.tif
#   inflating: /content/dataset/uk20K_v2/29951-N.tif
#   inflating: /content/dataset/uk20K_v2/568058-N.tif
#   inflating: /content/dataset/uk20K_v2/481489-N.tif
#   inflating: /content/dataset/uk20K_v2/236998-N.tif
#   inflating: /content/dataset/uk20K_v2/108665-P.tif
#   inflating: /content/dataset/uk20K_v2/127915-P.tif
#   inflating: /content/dataset/uk20K_v2/42580-P.tif
#   inflating: /content/dataset/uk20K_v2/181701-P.tif
#   inflating: /content/dataset/uk20K_v2/557764-N.tif
#   inflating: /content/dataset/uk20K_v2/59710-P.tif
#   inflating: /content/dataset/uk20K_v2/410557-N.tif
#   inflating: /content/dataset/uk20K_v2/45473-N.tif
#   inflating: /content/dataset/uk20K_v2/42491-N.tif
#   inflating: /content/dataset/uk20K_v2/136924-P.tif
#   inflating: /content/dataset/uk20K_v2/124936-P.tif
#   inflating: /content/dataset/uk20K_v2/164783-P.tif
#   inflating: /content/dataset/uk20K_v2/120972-P.tif
#   inflating: /content/dataset/uk20K_v2/159940-N.tif
#   inflating: /content/dataset/uk20K_v2/131809-P.tif
#   inflating: /content/dataset/uk20K_v2/250028-N.tif
#   inflating: /content/dataset/uk20K_v2/135990-P.tif
#   inflating: /content/dataset/uk20K_v2/7279-P.tif
#   inflating: /content/dataset/uk20K_v2/132830-P.tif
#   inflating: /content/dataset/uk20K_v2/67331-P.tif
#   inflating: /content/dataset/uk20K_v2/25226-P.tif
#   inflating: /content/dataset/uk20K_v2/45190-P.tif
#   inflating: /content/dataset/uk20K_v2/374346-N.tif
#   inflating: /content/dataset/uk20K_v2/511310-N.tif
#   inflating: /content/dataset/uk20K_v2/131045-P.tif
#   inflating: /content/dataset/uk20K_v2/146586-N.tif
#   inflating: /content/dataset/uk20K_v2/147642-P.tif
#   inflating: /content/dataset/uk20K_v2/136478-P.tif
#   inflating: /content/dataset/uk20K_v2/22841-N.tif
#   inflating: /content/dataset/uk20K_v2/421779-N.tif
#   inflating: /content/dataset/uk20K_v2/549790-N.tif
#   inflating: /content/dataset/uk20K_v2/329621-N.tif
#   inflating: /content/dataset/uk20K_v2/157201-P.tif
#   inflating: /content/dataset/uk20K_v2/362416-N.tif
#   inflating: /content/dataset/uk20K_v2/142099-P.tif
#   inflating: /content/dataset/uk20K_v2/703111-N.tif
#   inflating: /content/dataset/uk20K_v2/185951-N.tif
#   inflating: /content/dataset/uk20K_v2/494028-N.tif
#   inflating: /content/dataset/uk20K_v2/110021-P.tif
#   inflating: /content/dataset/uk20K_v2/113059-P.tif
#   inflating: /content/dataset/uk20K_v2/94010-P.tif
#   inflating: /content/dataset/uk20K_v2/177632-P.tif
#   inflating: /content/dataset/uk20K_v2/562334-N.tif
#   inflating: /content/dataset/uk20K_v2/455884-N.tif
#   inflating: /content/dataset/uk20K_v2/696985-N.tif
#   inflating: /content/dataset/uk20K_v2/44917-P.tif
#   inflating: /content/dataset/uk20K_v2/363777-N.tif
#   inflating: /content/dataset/uk20K_v2/20381-P.tif
#   inflating: /content/dataset/uk20K_v2/47917-P.tif
#   inflating: /content/dataset/uk20K_v2/2010-P.tif
#   inflating: /content/dataset/uk20K_v2/52930-N.tif
#   inflating: /content/dataset/uk20K_v2/218857-N.tif
#   inflating: /content/dataset/uk20K_v2/79400-P.tif
#   inflating: /content/dataset/uk20K_v2/52254-P.tif
#   inflating: /content/dataset/uk20K_v2/171709-P.tif
#   inflating: /content/dataset/uk20K_v2/3582-N.tif
#   inflating: /content/dataset/uk20K_v2/532442-N.tif
#   inflating: /content/dataset/uk20K_v2/307859-N.tif
#   inflating: /content/dataset/uk20K_v2/298261-N.tif
#   inflating: /content/dataset/uk20K_v2/97779-P.tif
#   inflating: /content/dataset/uk20K_v2/121357-P.tif
#   inflating: /content/dataset/uk20K_v2/67838-P.tif
#   inflating: /content/dataset/uk20K_v2/698403-N.tif
#   inflating: /content/dataset/uk20K_v2/453691-N.tif
#   inflating: /content/dataset/uk20K_v2/119923-P.tif
#   inflating: /content/dataset/uk20K_v2/114804-P.tif
#   inflating: /content/dataset/uk20K_v2/344154-N.tif
#   inflating: /content/dataset/uk20K_v2/420972-N.tif
#   inflating: /content/dataset/uk20K_v2/108157-P.tif
#   inflating: /content/dataset/uk20K_v2/92043-P.tif
#   inflating: /content/dataset/uk20K_v2/390540-N.tif
#   inflating: /content/dataset/uk20K_v2/434602-N.tif
#   inflating: /content/dataset/uk20K_v2/50990-N.tif
#   inflating: /content/dataset/uk20K_v2/167530-P.tif
#   inflating: /content/dataset/uk20K_v2/447185-N.tif
#   inflating: /content/dataset/uk20K_v2/195689-N.tif
#   inflating: /content/dataset/uk20K_v2/616547-N.tif
#   inflating: /content/dataset/uk20K_v2/579911-N.tif
#   inflating: /content/dataset/uk20K_v2/98129-P.tif
#   inflating: /content/dataset/uk20K_v2/365730-N.tif
#   inflating: /content/dataset/uk20K_v2/138486-P.tif
#   inflating: /content/dataset/uk20K_v2/297521-N.tif
#   inflating: /content/dataset/uk20K_v2/101601-P.tif
#   inflating: /content/dataset/uk20K_v2/90612-P.tif
#   inflating: /content/dataset/uk20K_v2/301120-N.tif
#   inflating: /content/dataset/uk20K_v2/42457-P.tif
#   inflating: /content/dataset/uk20K_v2/301271-N.tif
#   inflating: /content/dataset/uk20K_v2/22243-P.tif
#   inflating: /content/dataset/uk20K_v2/635462-N.tif
#   inflating: /content/dataset/uk20K_v2/105863-N.tif
#   inflating: /content/dataset/uk20K_v2/362546-N.tif
#   inflating: /content/dataset/uk20K_v2/78882-P.tif
#   inflating: /content/dataset/uk20K_v2/545478-N.tif
#   inflating: /content/dataset/uk20K_v2/42713-P.tif
#   inflating: /content/dataset/uk20K_v2/697373-N.tif
#   inflating: /content/dataset/uk20K_v2/420841-N.tif
#   inflating: /content/dataset/uk20K_v2/335742-N.tif
#   inflating: /content/dataset/uk20K_v2/79472-P.tif
#   inflating: /content/dataset/uk20K_v2/41369-N.tif
#   inflating: /content/dataset/uk20K_v2/9726-P.tif
#   inflating: /content/dataset/uk20K_v2/6734-P.tif
#   inflating: /content/dataset/uk20K_v2/298986-N.tif
#   inflating: /content/dataset/uk20K_v2/74169-P.tif
#   inflating: /content/dataset/uk20K_v2/157590-P.tif
#   inflating: /content/dataset/uk20K_v2/123592-P.tif
#   inflating: /content/dataset/uk20K_v2/156881-N.tif
#   inflating: /content/dataset/uk20K_v2/35196-P.tif
#   inflating: /content/dataset/uk20K_v2/21319-P.tif
#   inflating: /content/dataset/uk20K_v2/117449-P.tif
#   inflating: /content/dataset/uk20K_v2/103084-P.tif
#   inflating: /content/dataset/uk20K_v2/26750-P.tif
#   inflating: /content/dataset/uk20K_v2/30345-N.tif
#   inflating: /content/dataset/uk20K_v2/121398-P.tif
#   inflating: /content/dataset/uk20K_v2/656595-N.tif
#   inflating: /content/dataset/uk20K_v2/127133-P.tif
#   inflating: /content/dataset/uk20K_v2/605563-N.tif
#   inflating: /content/dataset/uk20K_v2/358375-N.tif
#   inflating: /content/dataset/uk20K_v2/46148-P.tif
#   inflating: /content/dataset/uk20K_v2/476799-N.tif
#   inflating: /content/dataset/uk20K_v2/101717-P.tif
#   inflating: /content/dataset/uk20K_v2/164639-P.tif
#   inflating: /content/dataset/uk20K_v2/19566-N.tif
#   inflating: /content/dataset/uk20K_v2/48242-N.tif
#   inflating: /content/dataset/uk20K_v2/473651-N.tif
#   inflating: /content/dataset/uk20K_v2/87822-P.tif
#   inflating: /content/dataset/uk20K_v2/133508-P.tif
#   inflating: /content/dataset/uk20K_v2/42954-P.tif
#   inflating: /content/dataset/uk20K_v2/138768-P.tif
#   inflating: /content/dataset/uk20K_v2/611810-N.tif
#   inflating: /content/dataset/uk20K_v2/133276-P.tif
#   inflating: /content/dataset/uk20K_v2/212982-N.tif
#   inflating: /content/dataset/uk20K_v2/102230-P.tif
#   inflating: /content/dataset/uk20K_v2/25222-P.tif
#   inflating: /content/dataset/uk20K_v2/171196-P.tif
#   inflating: /content/dataset/uk20K_v2/334952-N.tif
#   inflating: /content/dataset/uk20K_v2/91610-N.tif
#   inflating: /content/dataset/uk20K_v2/76737-P.tif
#   inflating: /content/dataset/uk20K_v2/731010-N.tif
#   inflating: /content/dataset/uk20K_v2/543670-N.tif
#   inflating: /content/dataset/uk20K_v2/53131-P.tif
#   inflating: /content/dataset/uk20K_v2/92371-P.tif
#   inflating: /content/dataset/uk20K_v2/71915-N.tif
#   inflating: /content/dataset/uk20K_v2/136015-P.tif
#   inflating: /content/dataset/uk20K_v2/148122-P.tif
#   inflating: /content/dataset/uk20K_v2/35685-N.tif
#   inflating: /content/dataset/uk20K_v2/246814-N.tif
#   inflating: /content/dataset/uk20K_v2/49056-P.tif
#   inflating: /content/dataset/uk20K_v2/228400-N.tif
#   inflating: /content/dataset/uk20K_v2/31100-P.tif
#   inflating: /content/dataset/uk20K_v2/169839-P.tif
#   inflating: /content/dataset/uk20K_v2/12090-N.tif
#   inflating: /content/dataset/uk20K_v2/24565-P.tif
#   inflating: /content/dataset/uk20K_v2/143838-P.tif
#   inflating: /content/dataset/uk20K_v2/533218-N.tif
#   inflating: /content/dataset/uk20K_v2/185241-N.tif
#   inflating: /content/dataset/uk20K_v2/643598-N.tif
#   inflating: /content/dataset/uk20K_v2/126533-N.tif
#   inflating: /content/dataset/uk20K_v2/724386-N.tif
#   inflating: /content/dataset/uk20K_v2/557361-N.tif
#   inflating: /content/dataset/uk20K_v2/78337-N.tif
#   inflating: /content/dataset/uk20K_v2/300474-N.tif
#   inflating: /content/dataset/uk20K_v2/332219-N.tif
#   inflating: /content/dataset/uk20K_v2/115172-P.tif
#   inflating: /content/dataset/uk20K_v2/576123-N.tif
#   inflating: /content/dataset/uk20K_v2/444942-N.tif
#   inflating: /content/dataset/uk20K_v2/137607-P.tif
#   inflating: /content/dataset/uk20K_v2/674653-N.tif
#   inflating: /content/dataset/uk20K_v2/178764-P.tif
#   inflating: /content/dataset/uk20K_v2/171744-P.tif
#   inflating: /content/dataset/uk20K_v2/130959-N.tif
#   inflating: /content/dataset/uk20K_v2/142739-P.tif
#   inflating: /content/dataset/uk20K_v2/151545-P.tif
#   inflating: /content/dataset/uk20K_v2/5442-P.tif
#   inflating: /content/dataset/uk20K_v2/609305-N.tif
#   inflating: /content/dataset/uk20K_v2/177150-P.tif
#   inflating: /content/dataset/uk20K_v2/14892-P.tif
#   inflating: /content/dataset/uk20K_v2/139288-P.tif
#   inflating: /content/dataset/uk20K_v2/136820-P.tif
#   inflating: /content/dataset/uk20K_v2/572727-N.tif
#   inflating: /content/dataset/uk20K_v2/527645-N.tif
#   inflating: /content/dataset/uk20K_v2/102080-P.tif
#   inflating: /content/dataset/uk20K_v2/608-P.tif
#   inflating: /content/dataset/uk20K_v2/46035-P.tif
#   inflating: /content/dataset/uk20K_v2/177632-N.tif
#   inflating: /content/dataset/uk20K_v2/328995-N.tif
#   inflating: /content/dataset/uk20K_v2/241402-N.tif
#   inflating: /content/dataset/uk20K_v2/187018-N.tif
#   inflating: /content/dataset/uk20K_v2/477471-N.tif
#   inflating: /content/dataset/uk20K_v2/101474-P.tif
#   inflating: /content/dataset/uk20K_v2/145424-N.tif
#   inflating: /content/dataset/uk20K_v2/147108-P.tif
#   inflating: /content/dataset/uk20K_v2/729678-N.tif
#   inflating: /content/dataset/uk20K_v2/683051-N.tif
#   inflating: /content/dataset/uk20K_v2/319420-N.tif
#   inflating: /content/dataset/uk20K_v2/662883-N.tif
#   inflating: /content/dataset/uk20K_v2/431898-N.tif
#   inflating: /content/dataset/uk20K_v2/32188-P.tif
#   inflating: /content/dataset/uk20K_v2/45443-P.tif
#   inflating: /content/dataset/uk20K_v2/149727-P.tif
#   inflating: /content/dataset/uk20K_v2/694155-N.tif
#   inflating: /content/dataset/uk20K_v2/611988-N.tif
#   inflating: /content/dataset/uk20K_v2/17501-P.tif
#   inflating: /content/dataset/uk20K_v2/559947-N.tif
#   inflating: /content/dataset/uk20K_v2/26801-P.tif
#   inflating: /content/dataset/uk20K_v2/183823-N.tif
#   inflating: /content/dataset/uk20K_v2/330762-N.tif
#   inflating: /content/dataset/uk20K_v2/134028-P.tif
#   inflating: /content/dataset/uk20K_v2/159886-N.tif
#   inflating: /content/dataset/uk20K_v2/141552-P.tif
#   inflating: /content/dataset/uk20K_v2/55056-P.tif
#   inflating: /content/dataset/uk20K_v2/344693-N.tif
#   inflating: /content/dataset/uk20K_v2/58792-P.tif
#   inflating: /content/dataset/uk20K_v2/110920-P.tif
#   inflating: /content/dataset/uk20K_v2/636716-N.tif
#   inflating: /content/dataset/uk20K_v2/571911-N.tif
#   inflating: /content/dataset/uk20K_v2/148947-P.tif
#   inflating: /content/dataset/uk20K_v2/55553-P.tif
#   inflating: /content/dataset/uk20K_v2/62498-P.tif
#   inflating: /content/dataset/uk20K_v2/398708-N.tif
#   inflating: /content/dataset/uk20K_v2/616742-N.tif
#   inflating: /content/dataset/uk20K_v2/560682-N.tif
#   inflating: /content/dataset/uk20K_v2/36708-P.tif
#   inflating: /content/dataset/uk20K_v2/737013-N.tif
#   inflating: /content/dataset/uk20K_v2/80076-N.tif
#   inflating: /content/dataset/uk20K_v2/438777-N.tif
#   inflating: /content/dataset/uk20K_v2/12259-P.tif
#   inflating: /content/dataset/uk20K_v2/126137-P.tif
#   inflating: /content/dataset/uk20K_v2/72329-P.tif
#   inflating: /content/dataset/uk20K_v2/166391-P.tif
#   inflating: /content/dataset/uk20K_v2/33446-P.tif
#   inflating: /content/dataset/uk20K_v2/42613-P.tif
#   inflating: /content/dataset/uk20K_v2/174871-N.tif
#   inflating: /content/dataset/uk20K_v2/138804-P.tif
#   inflating: /content/dataset/uk20K_v2/126259-N.tif
#   inflating: /content/dataset/uk20K_v2/58523-P.tif
#   inflating: /content/dataset/uk20K_v2/106546-P.tif
#   inflating: /content/dataset/uk20K_v2/58468-N.tif
#   inflating: /content/dataset/uk20K_v2/536559-N.tif
#   inflating: /content/dataset/uk20K_v2/160848-P.tif
#   inflating: /content/dataset/uk20K_v2/573574-N.tif
#   inflating: /content/dataset/uk20K_v2/42903-P.tif
#   inflating: /content/dataset/uk20K_v2/211522-N.tif
#   inflating: /content/dataset/uk20K_v2/74390-P.tif
#   inflating: /content/dataset/uk20K_v2/132285-P.tif
#   inflating: /content/dataset/uk20K_v2/269339-N.tif
#   inflating: /content/dataset/uk20K_v2/52329-P.tif
#   inflating: /content/dataset/uk20K_v2/154769-P.tif
#   inflating: /content/dataset/uk20K_v2/9657-P.tif
#   inflating: /content/dataset/uk20K_v2/403605-N.tif
#   inflating: /content/dataset/uk20K_v2/310488-N.tif
#   inflating: /content/dataset/uk20K_v2/483575-N.tif
#   inflating: /content/dataset/uk20K_v2/21312-P.tif
#   inflating: /content/dataset/uk20K_v2/142759-P.tif
#   inflating: /content/dataset/uk20K_v2/36460-P.tif
#   inflating: /content/dataset/uk20K_v2/150706-P.tif
#   inflating: /content/dataset/uk20K_v2/309314-N.tif
#   inflating: /content/dataset/uk20K_v2/20075-N.tif
#   inflating: /content/dataset/uk20K_v2/368515-N.tif
#   inflating: /content/dataset/uk20K_v2/123964-N.tif
#   inflating: /content/dataset/uk20K_v2/98277-P.tif
#   inflating: /content/dataset/uk20K_v2/34533-N.tif
#   inflating: /content/dataset/uk20K_v2/90328-P.tif
#   inflating: /content/dataset/uk20K_v2/609277-N.tif
#   inflating: /content/dataset/uk20K_v2/64362-P.tif
#   inflating: /content/dataset/uk20K_v2/584982-N.tif
#   inflating: /content/dataset/uk20K_v2/66576-P.tif
#   inflating: /content/dataset/uk20K_v2/499571-N.tif
#   inflating: /content/dataset/uk20K_v2/308075-N.tif
#   inflating: /content/dataset/uk20K_v2/35053-P.tif
#   inflating: /content/dataset/uk20K_v2/389573-N.tif
#   inflating: /content/dataset/uk20K_v2/16681-N.tif
#   inflating: /content/dataset/uk20K_v2/136147-P.tif
#   inflating: /content/dataset/uk20K_v2/445277-N.tif
#   inflating: /content/dataset/uk20K_v2/713146-N.tif
#   inflating: /content/dataset/uk20K_v2/87917-P.tif
#   inflating: /content/dataset/uk20K_v2/143416-N.tif
#   inflating: /content/dataset/uk20K_v2/96087-P.tif
#   inflating: /content/dataset/uk20K_v2/162040-P.tif
#   inflating: /content/dataset/uk20K_v2/60081-N.tif
#   inflating: /content/dataset/uk20K_v2/503357-N.tif
#   inflating: /content/dataset/uk20K_v2/157766-P.tif
#   inflating: /content/dataset/uk20K_v2/476918-N.tif
#   inflating: /content/dataset/uk20K_v2/24738-N.tif
#   inflating: /content/dataset/uk20K_v2/105244-N.tif
#   inflating: /content/dataset/uk20K_v2/170915-N.tif
#   inflating: /content/dataset/uk20K_v2/159950-P.tif
#   inflating: /content/dataset/uk20K_v2/3866-P.tif
#   inflating: /content/dataset/uk20K_v2/208416-N.tif
#   inflating: /content/dataset/uk20K_v2/434839-N.tif
#   inflating: /content/dataset/uk20K_v2/572127-N.tif
#   inflating: /content/dataset/uk20K_v2/618356-N.tif
#   inflating: /content/dataset/uk20K_v2/647329-N.tif
#   inflating: /content/dataset/uk20K_v2/2746-P.tif
#   inflating: /content/dataset/uk20K_v2/444810-N.tif
#   inflating: /content/dataset/uk20K_v2/578341-N.tif
#   inflating: /content/dataset/uk20K_v2/140413-P.tif
#   inflating: /content/dataset/uk20K_v2/126409-P.tif
#   inflating: /content/dataset/uk20K_v2/347332-N.tif
#   inflating: /content/dataset/uk20K_v2/380614-N.tif
#   inflating: /content/dataset/uk20K_v2/200280-N.tif
#   inflating: /content/dataset/uk20K_v2/107429-N.tif
#   inflating: /content/dataset/uk20K_v2/427622-N.tif
#   inflating: /content/dataset/uk20K_v2/146783-P.tif
#   inflating: /content/dataset/uk20K_v2/128832-P.tif
#   inflating: /content/dataset/uk20K_v2/183784-N.tif
#   inflating: /content/dataset/uk20K_v2/72606-P.tif
#   inflating: /content/dataset/uk20K_v2/302385-N.tif
#   inflating: /content/dataset/uk20K_v2/244037-N.tif
#   inflating: /content/dataset/uk20K_v2/726612-N.tif
#   inflating: /content/dataset/uk20K_v2/104020-N.tif
#   inflating: /content/dataset/uk20K_v2/220852-N.tif
#   inflating: /content/dataset/uk20K_v2/372254-N.tif
#   inflating: /content/dataset/uk20K_v2/535291-N.tif
#   inflating: /content/dataset/uk20K_v2/140304-P.tif
#   inflating: /content/dataset/uk20K_v2/110419-N.tif
#   inflating: /content/dataset/uk20K_v2/65414-P.tif
#   inflating: /content/dataset/uk20K_v2/472538-N.tif
#   inflating: /content/dataset/uk20K_v2/482396-N.tif
#   inflating: /content/dataset/uk20K_v2/360747-N.tif
#   inflating: /content/dataset/uk20K_v2/25778-P.tif
#   inflating: /content/dataset/uk20K_v2/110513-P.tif
#   inflating: /content/dataset/uk20K_v2/398787-N.tif
#   inflating: /content/dataset/uk20K_v2/84574-P.tif
#   inflating: /content/dataset/uk20K_v2/16398-P.tif
#   inflating: /content/dataset/uk20K_v2/580575-N.tif
#   inflating: /content/dataset/uk20K_v2/125695-P.tif
#   inflating: /content/dataset/uk20K_v2/75549-P.tif
#   inflating: /content/dataset/uk20K_v2/41544-P.tif
#   inflating: /content/dataset/uk20K_v2/10888-P.tif
#   inflating: /content/dataset/uk20K_v2/203417-N.tif
#   inflating: /content/dataset/uk20K_v2/172275-N.tif
#   inflating: /content/dataset/uk20K_v2/162900-P.tif
#   inflating: /content/dataset/uk20K_v2/257136-N.tif
#   inflating: /content/dataset/uk20K_v2/9995-P.tif
#   inflating: /content/dataset/uk20K_v2/37053-P.tif
#   inflating: /content/dataset/uk20K_v2/176497-N.tif
#   inflating: /content/dataset/uk20K_v2/573870-N.tif
#   inflating: /content/dataset/uk20K_v2/139948-P.tif
#   inflating: /content/dataset/uk20K_v2/649386-N.tif
#   inflating: /content/dataset/uk20K_v2/167518-P.tif
#   inflating: /content/dataset/uk20K_v2/35825-P.tif
#   inflating: /content/dataset/uk20K_v2/556410-N.tif
#   inflating: /content/dataset/uk20K_v2/42699-N.tif
#   inflating: /content/dataset/uk20K_v2/59869-P.tif
#   inflating: /content/dataset/uk20K_v2/49066-N.tif
#   inflating: /content/dataset/uk20K_v2/50256-P.tif
#   inflating: /content/dataset/uk20K_v2/162908-P.tif
#   inflating: /content/dataset/uk20K_v2/62713-P.tif
#   inflating: /content/dataset/uk20K_v2/319757-N.tif
#   inflating: /content/dataset/uk20K_v2/228615-N.tif
#   inflating: /content/dataset/uk20K_v2/689092-N.tif
#   inflating: /content/dataset/uk20K_v2/29176-P.tif
#   inflating: /content/dataset/uk20K_v2/689363-N.tif
#   inflating: /content/dataset/uk20K_v2/21528-P.tif
#   inflating: /content/dataset/uk20K_v2/163611-P.tif
#   inflating: /content/dataset/uk20K_v2/8889-P.tif
#   inflating: /content/dataset/uk20K_v2/127961-P.tif
#   inflating: /content/dataset/uk20K_v2/11137-N.tif
#   inflating: /content/dataset/uk20K_v2/38038-P.tif
#   inflating: /content/dataset/uk20K_v2/611630-N.tif
#   inflating: /content/dataset/uk20K_v2/23101-N.tif
#   inflating: /content/dataset/uk20K_v2/172830-P.tif
#   inflating: /content/dataset/uk20K_v2/79479-N.tif
#   inflating: /content/dataset/uk20K_v2/535737-N.tif
#   inflating: /content/dataset/uk20K_v2/408218-N.tif
#   inflating: /content/dataset/uk20K_v2/60786-N.tif
#   inflating: /content/dataset/uk20K_v2/94436-P.tif
#   inflating: /content/dataset/uk20K_v2/135216-P.tif
#   inflating: /content/dataset/uk20K_v2/92015-P.tif
#   inflating: /content/dataset/uk20K_v2/234078-N.tif
#   inflating: /content/dataset/uk20K_v2/7828-P.tif
#   inflating: /content/dataset/uk20K_v2/468050-N.tif
#   inflating: /content/dataset/uk20K_v2/586596-N.tif
#   inflating: /content/dataset/uk20K_v2/130848-P.tif
#   inflating: /content/dataset/uk20K_v2/158991-N.tif
#   inflating: /content/dataset/uk20K_v2/379477-N.tif
#   inflating: /content/dataset/uk20K_v2/24118-P.tif
#   inflating: /content/dataset/uk20K_v2/535221-N.tif
#   inflating: /content/dataset/uk20K_v2/123265-P.tif
#   inflating: /content/dataset/uk20K_v2/30079-P.tif
#   inflating: /content/dataset/uk20K_v2/41100-P.tif
#   inflating: /content/dataset/uk20K_v2/148672-N.tif
#   inflating: /content/dataset/uk20K_v2/706418-N.tif
#   inflating: /content/dataset/uk20K_v2/518982-N.tif
#   inflating: /content/dataset/uk20K_v2/577165-N.tif
#   inflating: /content/dataset/uk20K_v2/583207-N.tif
#   inflating: /content/dataset/uk20K_v2/93493-P.tif
#   inflating: /content/dataset/uk20K_v2/691139-N.tif
#   inflating: /content/dataset/uk20K_v2/357871-N.tif
#   inflating: /content/dataset/uk20K_v2/320128-N.tif
#   inflating: /content/dataset/uk20K_v2/127461-P.tif
#   inflating: /content/dataset/uk20K_v2/152522-N.tif
#   inflating: /content/dataset/uk20K_v2/7881-P.tif
#   inflating: /content/dataset/uk20K_v2/145954-P.tif
#   inflating: /content/dataset/uk20K_v2/67411-P.tif
#   inflating: /content/dataset/uk20K_v2/41512-P.tif
#   inflating: /content/dataset/uk20K_v2/28452-P.tif
#   inflating: /content/dataset/uk20K_v2/623547-N.tif
#   inflating: /content/dataset/uk20K_v2/13260-P.tif
#   inflating: /content/dataset/uk20K_v2/2270-P.tif
#   inflating: /content/dataset/uk20K_v2/159814-P.tif
#   inflating: /content/dataset/uk20K_v2/93187-N.tif
#   inflating: /content/dataset/uk20K_v2/566523-N.tif
#   inflating: /content/dataset/uk20K_v2/375508-N.tif
#   inflating: /content/dataset/uk20K_v2/140432-N.tif
#   inflating: /content/dataset/uk20K_v2/80964-P.tif
#   inflating: /content/dataset/uk20K_v2/287779-N.tif
#   inflating: /content/dataset/uk20K_v2/68710-P.tif
#   inflating: /content/dataset/uk20K_v2/120448-P.tif
#   inflating: /content/dataset/uk20K_v2/48181-P.tif
#   inflating: /content/dataset/uk20K_v2/5670-P.tif
#   inflating: /content/dataset/uk20K_v2/38698-P.tif
#   inflating: /content/dataset/uk20K_v2/87206-P.tif
#   inflating: /content/dataset/uk20K_v2/79429-P.tif
#   inflating: /content/dataset/uk20K_v2/35860-P.tif
#   inflating: /content/dataset/uk20K_v2/250462-N.tif
#   inflating: /content/dataset/uk20K_v2/67429-N.tif
#   inflating: /content/dataset/uk20K_v2/257261-N.tif
#   inflating: /content/dataset/uk20K_v2/495572-N.tif
#   inflating: /content/dataset/uk20K_v2/64332-N.tif
#   inflating: /content/dataset/uk20K_v2/158650-P.tif
#   inflating: /content/dataset/uk20K_v2/72932-P.tif
#   inflating: /content/dataset/uk20K_v2/147625-P.tif
#   inflating: /content/dataset/uk20K_v2/149501-P.tif
#   inflating: /content/dataset/uk20K_v2/99984-P.tif
#   inflating: /content/dataset/uk20K_v2/625655-N.tif
#   inflating: /content/dataset/uk20K_v2/45261-P.tif
#   inflating: /content/dataset/uk20K_v2/14747-P.tif
#   inflating: /content/dataset/uk20K_v2/535892-N.tif
#   inflating: /content/dataset/uk20K_v2/103878-P.tif
#   inflating: /content/dataset/uk20K_v2/245307-N.tif
#   inflating: /content/dataset/uk20K_v2/152940-P.tif
#   inflating: /content/dataset/uk20K_v2/121840-P.tif
#   inflating: /content/dataset/uk20K_v2/54140-P.tif
#   inflating: /content/dataset/uk20K_v2/78671-P.tif
#   inflating: /content/dataset/uk20K_v2/679098-N.tif
#   inflating: /content/dataset/uk20K_v2/135138-P.tif
#   inflating: /content/dataset/uk20K_v2/579860-N.tif
#   inflating: /content/dataset/uk20K_v2/9417-N.tif
#   inflating: /content/dataset/uk20K_v2/105670-P.tif
#   inflating: /content/dataset/uk20K_v2/117557-P.tif
#   inflating: /content/dataset/uk20K_v2/4667-N.tif
#   inflating: /content/dataset/uk20K_v2/276080-N.tif
#   inflating: /content/dataset/uk20K_v2/4200-P.tif
#   inflating: /content/dataset/uk20K_v2/172571-P.tif
#   inflating: /content/dataset/uk20K_v2/87857-P.tif
#   inflating: /content/dataset/uk20K_v2/86033-N.tif
#   inflating: /content/dataset/uk20K_v2/733888-N.tif
#   inflating: /content/dataset/uk20K_v2/635838-N.tif
#   inflating: /content/dataset/uk20K_v2/64765-P.tif
#   inflating: /content/dataset/uk20K_v2/139513-N.tif
#   inflating: /content/dataset/uk20K_v2/625293-N.tif
#   inflating: /content/dataset/uk20K_v2/151190-P.tif
#   inflating: /content/dataset/uk20K_v2/120852-P.tif
#   inflating: /content/dataset/uk20K_v2/128698-P.tif
#   inflating: /content/dataset/uk20K_v2/426880-N.tif
#   inflating: /content/dataset/uk20K_v2/131469-P.tif
#   inflating: /content/dataset/uk20K_v2/243974-N.tif
#   inflating: /content/dataset/uk20K_v2/584777-N.tif
#   inflating: /content/dataset/uk20K_v2/127494-P.tif
#   inflating: /content/dataset/uk20K_v2/199915-N.tif
#   inflating: /content/dataset/uk20K_v2/169913-P.tif
#   inflating: /content/dataset/uk20K_v2/123687-N.tif
#   inflating: /content/dataset/uk20K_v2/41079-P.tif
#   inflating: /content/dataset/uk20K_v2/147784-P.tif
#   inflating: /content/dataset/uk20K_v2/582062-N.tif
#   inflating: /content/dataset/uk20K_v2/735877-N.tif
#   inflating: /content/dataset/uk20K_v2/383256-N.tif
#   inflating: /content/dataset/uk20K_v2/52000-P.tif
#   inflating: /content/dataset/uk20K_v2/237539-N.tif
#   inflating: /content/dataset/uk20K_v2/530762-N.tif
#   inflating: /content/dataset/uk20K_v2/514379-N.tif
#   inflating: /content/dataset/uk20K_v2/99047-P.tif
#   inflating: /content/dataset/uk20K_v2/89779-P.tif
#   inflating: /content/dataset/uk20K_v2/37031-P.tif
#   inflating: /content/dataset/uk20K_v2/112737-P.tif
#   inflating: /content/dataset/uk20K_v2/41906-P.tif
#   inflating: /content/dataset/uk20K_v2/39937-N.tif
#   inflating: /content/dataset/uk20K_v2/10781-N.tif
#   inflating: /content/dataset/uk20K_v2/393237-N.tif
#   inflating: /content/dataset/uk20K_v2/92169-P.tif
#   inflating: /content/dataset/uk20K_v2/69889-N.tif
#   inflating: /content/dataset/uk20K_v2/124654-P.tif
#   inflating: /content/dataset/uk20K_v2/173564-P.tif
#   inflating: /content/dataset/uk20K_v2/48387-P.tif
#   inflating: /content/dataset/uk20K_v2/119519-P.tif
#   inflating: /content/dataset/uk20K_v2/152196-N.tif
#   inflating: /content/dataset/uk20K_v2/101240-P.tif
#   inflating: /content/dataset/uk20K_v2/112883-P.tif
#   inflating: /content/dataset/uk20K_v2/161734-P.tif
#   inflating: /content/dataset/uk20K_v2/7622-P.tif
#   inflating: /content/dataset/uk20K_v2/503241-N.tif
#   inflating: /content/dataset/uk20K_v2/60912-P.tif
#   inflating: /content/dataset/uk20K_v2/34238-N.tif
#   inflating: /content/dataset/uk20K_v2/730232-N.tif
#   inflating: /content/dataset/uk20K_v2/175636-N.tif
#   inflating: /content/dataset/uk20K_v2/75-P.tif
#   inflating: /content/dataset/uk20K_v2/24215-P.tif
#   inflating: /content/dataset/uk20K_v2/171111-N.tif
#   inflating: /content/dataset/uk20K_v2/113320-P.tif
#   inflating: /content/dataset/uk20K_v2/205514-N.tif
#   inflating: /content/dataset/uk20K_v2/20154-N.tif
#   inflating: /content/dataset/uk20K_v2/181511-P.tif
#   inflating: /content/dataset/uk20K_v2/477045-N.tif
#   inflating: /content/dataset/uk20K_v2/24089-N.tif
#   inflating: /content/dataset/uk20K_v2/713152-N.tif
#   inflating: /content/dataset/uk20K_v2/500122-N.tif
#   inflating: /content/dataset/uk20K_v2/166564-P.tif
#   inflating: /content/dataset/uk20K_v2/23207-P.tif
#   inflating: /content/dataset/uk20K_v2/135792-N.tif
#   inflating: /content/dataset/uk20K_v2/704403-N.tif
#   inflating: /content/dataset/uk20K_v2/530447-N.tif
#   inflating: /content/dataset/uk20K_v2/477271-N.tif
#   inflating: /content/dataset/uk20K_v2/502721-N.tif
#   inflating: /content/dataset/uk20K_v2/36689-P.tif
#   inflating: /content/dataset/uk20K_v2/45456-P.tif
#   inflating: /content/dataset/uk20K_v2/166189-P.tif
#   inflating: /content/dataset/uk20K_v2/204564-N.tif
#   inflating: /content/dataset/uk20K_v2/82371-N.tif
#   inflating: /content/dataset/uk20K_v2/120362-P.tif
#   inflating: /content/dataset/uk20K_v2/36015-P.tif
#   inflating: /content/dataset/uk20K_v2/54986-N.tif
#   inflating: /content/dataset/uk20K_v2/52618-P.tif
#   inflating: /content/dataset/uk20K_v2/498556-N.tif
#   inflating: /content/dataset/uk20K_v2/128633-P.tif
#   inflating: /content/dataset/uk20K_v2/622108-N.tif
#   inflating: /content/dataset/uk20K_v2/178914-P.tif
#   inflating: /content/dataset/uk20K_v2/120969-P.tif
#   inflating: /content/dataset/uk20K_v2/95703-P.tif
#   inflating: /content/dataset/uk20K_v2/22496-P.tif
#   inflating: /content/dataset/uk20K_v2/349186-N.tif
#   inflating: /content/dataset/uk20K_v2/556657-N.tif
#   inflating: /content/dataset/uk20K_v2/146343-N.tif
#   inflating: /content/dataset/uk20K_v2/267405-N.tif
#   inflating: /content/dataset/uk20K_v2/279197-N.tif
#   inflating: /content/dataset/uk20K_v2/96948-P.tif
#   inflating: /content/dataset/uk20K_v2/145325-P.tif
#   inflating: /content/dataset/uk20K_v2/189556-N.tif
#   inflating: /content/dataset/uk20K_v2/82390-P.tif
#   inflating: /content/dataset/uk20K_v2/109655-P.tif
#   inflating: /content/dataset/uk20K_v2/91683-P.tif
#   inflating: /content/dataset/uk20K_v2/111631-P.tif
#   inflating: /content/dataset/uk20K_v2/27530-N.tif
#   inflating: /content/dataset/uk20K_v2/96132-P.tif
#   inflating: /content/dataset/uk20K_v2/284277-N.tif
#   inflating: /content/dataset/uk20K_v2/11053-P.tif
#   inflating: /content/dataset/uk20K_v2/31230-P.tif
#   inflating: /content/dataset/uk20K_v2/709976-N.tif
#   inflating: /content/dataset/uk20K_v2/317036-N.tif
#   inflating: /content/dataset/uk20K_v2/649919-N.tif
#   inflating: /content/dataset/uk20K_v2/553738-N.tif
#   inflating: /content/dataset/uk20K_v2/709066-N.tif
#   inflating: /content/dataset/uk20K_v2/109505-P.tif
#   inflating: /content/dataset/uk20K_v2/712987-N.tif
# ...
#   inflating: /content/dataset/uk20K_v2/375971-N.tif
#   inflating: /content/dataset/uk20K_v2/178435-P.tif
#   inflating: /content/dataset/uk20K_v2/331039-N.tif
#   inflating: /content/dataset/uk20K_v2/47695-P.tif
#   inflating: /content/dataset/uk20K_v2/162472-P.tif
#   inflating: /content/dataset/uk20K_v2/141599-N.tif
#   inflating: /content/dataset/uk20K_v2/306665-N.tif
#   inflating: /content/dataset/uk20K_v2/480209-N.tif
#   inflating: /content/dataset/uk20K_v2/98789-P.tif
#   inflating: /content/dataset/uk20K_v2/142977-P.tif
#   inflating: /content/dataset/uk20K_v2/383306-N.tif
#   inflating: /content/dataset/uk20K_v2/38778-P.tif
#   inflating: /content/dataset/uk20K_v2/46905-P.tif
#   inflating: /content/dataset/uk20K_v2/119170-P.tif
#   inflating: /content/dataset/uk20K_v2/106551-P.tif
#   inflating: /content/dataset/uk20K_v2/210278-N.tif
#   inflating: /content/dataset/uk20K_v2/15280-P.tif
#   inflating: /content/dataset/uk20K_v2/434679-N.tif
#   inflating: /content/dataset/uk20K_v2/129973-P.tif
#   inflating: /content/dataset/uk20K_v2/336484-N.tif
#   inflating: /content/dataset/uk20K_v2/161018-P.tif
#   inflating: /content/dataset/uk20K_v2/55125-P.tif
#   inflating: /content/dataset/uk20K_v2/83245-P.tif
#   inflating: /content/dataset/uk20K_v2/214647-N.tif
#   inflating: /content/dataset/uk20K_v2/46825-N.tif
#   inflating: /content/dataset/uk20K_v2/145999-P.tif
#   inflating: /content/dataset/uk20K_v2/335348-N.tif
#   inflating: /content/dataset/uk20K_v2/153754-P.tif
#   inflating: /content/dataset/uk20K_v2/331835-N.tif
#   inflating: /content/dataset/uk20K_v2/174884-P.tif
#   inflating: /content/dataset/uk20K_v2/679560-N.tif
#   inflating: /content/dataset/uk20K_v2/146876-N.tif
#   inflating: /content/dataset/uk20K_v2/74786-P.tif
#   inflating: /content/dataset/uk20K_v2/564602-N.tif
#   inflating: /content/dataset/uk20K_v2/74074-P.tif
#   inflating: /content/dataset/uk20K_v2/156042-N.tif
#   inflating: /content/dataset/uk20K_v2/176673-P.tif
#   inflating: /content/dataset/uk20K_v2/43127-P.tif
#   inflating: /content/dataset/uk20K_v2/121588-P.tif
#   inflating: /content/dataset/uk20K_v2/135466-N.tif
#   inflating: /content/dataset/uk20K_v2/33260-P.tif
#   inflating: /content/dataset/uk20K_v2/226281-N.tif
#   inflating: /content/dataset/uk20K_v2/36879-N.tif
#   inflating: /content/dataset/uk20K_v2/473798-N.tif
#   inflating: /content/dataset/uk20K_v2/101472-P.tif
#   inflating: /content/dataset/uk20K_v2/674882-N.tif
#   inflating: /content/dataset/uk20K_v2/168859-P.tif
#   inflating: /content/dataset/uk20K_v2/478033-N.tif
#   inflating: /content/dataset/uk20K_v2/35781-P.tif
#   inflating: /content/dataset/uk20K_v2/144452-P.tif
#   inflating: /content/dataset/uk20K_v2/379038-N.tif
#   inflating: /content/dataset/uk20K_v2/37105-P.tif
#   inflating: /content/dataset/uk20K_v2/55001-N.tif
#   inflating: /content/dataset/uk20K_v2/581583-N.tif
#   inflating: /content/dataset/uk20K_v2/144492-P.tif
#   inflating: /content/dataset/uk20K_v2/148520-P.tif
#   inflating: /content/dataset/uk20K_v2/434192-N.tif
#   inflating: /content/dataset/uk20K_v2/52128-P.tif
#   inflating: /content/dataset/uk20K_v2/379983-N.tif
#   inflating: /content/dataset/uk20K_v2/53367-N.tif
#   inflating: /content/dataset/uk20K_v2/26963-N.tif
#   inflating: /content/dataset/uk20K_v2/56246-N.tif
#   inflating: /content/dataset/uk20K_v2/19092-P.tif
#   inflating: /content/dataset/uk20K_v2/99834-P.tif
#   inflating: /content/dataset/uk20K_v2/2441-P.tif
#   inflating: /content/dataset/uk20K_v2/433879-N.tif
#   inflating: /content/dataset/uk20K_v2/351143-N.tif
#   inflating: /content/dataset/uk20K_v2/41429-N.tif
#   inflating: /content/dataset/uk20K_v2/53755-P.tif
#   inflating: /content/dataset/uk20K_v2/155547-P.tif
#   inflating: /content/dataset/uk20K_v2/88346-P.tif
#   inflating: /content/dataset/uk20K_v2/180469-P.tif
#   inflating: /content/dataset/uk20K_v2/140046-P.tif
#   inflating: /content/dataset/uk20K_v2/35234-P.tif
#   inflating: /content/dataset/uk20K_v2/105004-P.tif
#   inflating: /content/dataset/uk20K_v2/73150-P.tif
#   inflating: /content/dataset/uk20K_v2/681680-N.tif
#   inflating: /content/dataset/uk20K_v2/358604-N.tif
#   inflating: /content/dataset/uk20K_v2/519752-N.tif
#   inflating: /content/dataset/uk20K_v2/351269-N.tif
#   inflating: /content/dataset/uk20K_v2/379719-N.tif
#   inflating: /content/dataset/uk20K_v2/643034-N.tif
#   inflating: /content/dataset/uk20K_v2/288626-N.tif
#   inflating: /content/dataset/uk20K_v2/652098-N.tif
#   inflating: /content/dataset/uk20K_v2/496449-N.tif
#   inflating: /content/dataset/uk20K_v2/137152-P.tif
#   inflating: /content/dataset/uk20K_v2/50756-P.tif
#   inflating: /content/dataset/uk20K_v2/670494-N.tif
#   inflating: /content/dataset/uk20K_v2/487251-N.tif
#   inflating: /content/dataset/uk20K_v2/7466-P.tif
#   inflating: /content/dataset/uk20K_v2/219703-N.tif
#   inflating: /content/dataset/uk20K_v2/93731-P.tif
#   inflating: /content/dataset/uk20K_v2/123118-N.tif
#   inflating: /content/dataset/uk20K_v2/78591-P.tif
#   inflating: /content/dataset/uk20K_v2/571968-N.tif
#   inflating: /content/dataset/uk20K_v2/323158-N.tif
#   inflating: /content/dataset/uk20K_v2/37649-P.tif
#   inflating: /content/dataset/uk20K_v2/264422-N.tif
#   inflating: /content/dataset/uk20K_v2/106269-P.tif
#   inflating: /content/dataset/uk20K_v2/151193-P.tif
#   inflating: /content/dataset/uk20K_v2/86198-P.tif
#   inflating: /content/dataset/uk20K_v2/139147-P.tif
#   inflating: /content/dataset/uk20K_v2/201758-N.tif
#   inflating: /content/dataset/uk20K_v2/335951-N.tif
#   inflating: /content/dataset/uk20K_v2/272649-N.tif
#   inflating: /content/dataset/uk20K_v2/430758-N.tif
#   inflating: /content/dataset/uk20K_v2/130191-P.tif
#   inflating: /content/dataset/uk20K_v2/418157-N.tif
#   inflating: /content/dataset/uk20K_v2/152436-P.tif
#   inflating: /content/dataset/uk20K_v2/363587-N.tif
#   inflating: /content/dataset/uk20K_v2/50165-P.tif
#   inflating: /content/dataset/uk20K_v2/80531-P.tif
#   inflating: /content/dataset/uk20K_v2/89423-P.tif
#   inflating: /content/dataset/uk20K_v2/474236-N.tif
#   inflating: /content/dataset/uk20K_v2/43979-P.tif
#   inflating: /content/dataset/uk20K_v2/72163-P.tif
#   inflating: /content/dataset/uk20K_v2/47673-N.tif
#   inflating: /content/dataset/uk20K_v2/48711-P.tif
#   inflating: /content/dataset/uk20K_v2/16763-P.tif
#   inflating: /content/dataset/uk20K_v2/154839-P.tif
#   inflating: /content/dataset/uk20K_v2/7380-P.tif
#   inflating: /content/dataset/uk20K_v2/235466-N.tif
#   inflating: /content/dataset/uk20K_v2/84238-P.tif
#   inflating: /content/dataset/uk20K_v2/157311-P.tif
#   inflating: /content/dataset/uk20K_v2/175845-P.tif
#   inflating: /content/dataset/uk20K_v2/80835-P.tif
#   inflating: /content/dataset/uk20K_v2/679050-N.tif
#   inflating: /content/dataset/uk20K_v2/370483-N.tif
#   inflating: /content/dataset/uk20K_v2/117255-P.tif
#   inflating: /content/dataset/uk20K_v2/15107-P.tif
#   inflating: /content/dataset/uk20K_v2/62212-P.tif
#   inflating: /content/dataset/uk20K_v2/65531-P.tif
#   inflating: /content/dataset/uk20K_v2/17581-P.tif
#   inflating: /content/dataset/uk20K_v2/661595-N.tif
#   inflating: /content/dataset/uk20K_v2/115573-P.tif
#   inflating: /content/dataset/uk20K_v2/109789-P.tif
#   inflating: /content/dataset/uk20K_v2/4802-N.tif
#   inflating: /content/dataset/uk20K_v2/23722-P.tif
#   inflating: /content/dataset/uk20K_v2/370398-N.tif
#   inflating: /content/dataset/uk20K_v2/248454-N.tif
#   inflating: /content/dataset/uk20K_v2/525251-N.tif
#   inflating: /content/dataset/uk20K_v2/29423-N.tif
#   inflating: /content/dataset/uk20K_v2/457325-N.tif
#   inflating: /content/dataset/uk20K_v2/74419-P.tif
#   inflating: /content/dataset/uk20K_v2/134880-P.tif
#   inflating: /content/dataset/uk20K_v2/111011-P.tif
#   inflating: /content/dataset/uk20K_v2/69427-P.tif
#   inflating: /content/dataset/uk20K_v2/22336-N.tif
#   inflating: /content/dataset/uk20K_v2/224198-N.tif
#   inflating: /content/dataset/uk20K_v2/508154-N.tif
#   inflating: /content/dataset/uk20K_v2/37120-P.tif
#   inflating: /content/dataset/uk20K_v2/381531-N.tif
#   inflating: /content/dataset/uk20K_v2/376836-N.tif
#   inflating: /content/dataset/uk20K_v2/170948-N.tif
#   inflating: /content/dataset/uk20K_v2/149429-N.tif
#   inflating: /content/dataset/uk20K_v2/464534-N.tif
#   inflating: /content/dataset/uk20K_v2/156897-P.tif
#   inflating: /content/dataset/uk20K_v2/139819-P.tif
#   inflating: /content/dataset/uk20K_v2/194956-N.tif
#   inflating: /content/dataset/uk20K_v2/673116-N.tif
#   inflating: /content/dataset/uk20K_v2/79660-P.tif
#   inflating: /content/dataset/uk20K_v2/125115-P.tif
#   inflating: /content/dataset/uk20K_v2/31356-P.tif
#   inflating: /content/dataset/uk20K_v2/720111-N.tif
#   inflating: /content/dataset/uk20K_v2/102853-N.tif
#   inflating: /content/dataset/uk20K_v2/53112-P.tif
#   inflating: /content/dataset/uk20K_v2/115189-P.tif
#   inflating: /content/dataset/uk20K_v2/34604-P.tif
#   inflating: /content/dataset/uk20K_v2/84940-P.tif
#   inflating: /content/dataset/uk20K_v2/13196-P.tif
#   inflating: /content/dataset/uk20K_v2/153372-P.tif
#   inflating: /content/dataset/uk20K_v2/99566-P.tif
#   inflating: /content/dataset/uk20K_v2/283167-N.tif
#   inflating: /content/dataset/uk20K_v2/105789-P.tif
#   inflating: /content/dataset/uk20K_v2/1892-P.tif
#   inflating: /content/dataset/uk20K_v2/142693-P.tif
#   inflating: /content/dataset/uk20K_v2/606454-N.tif
#   inflating: /content/dataset/uk20K_v2/715022-N.tif
#   inflating: /content/dataset/uk20K_v2/708219-N.tif
#   inflating: /content/dataset/uk20K_v2/689939-N.tif
#   inflating: /content/dataset/uk20K_v2/29343-P.tif
#   inflating: /content/dataset/uk20K_v2/705276-N.tif
#   inflating: /content/dataset/uk20K_v2/119037-P.tif
#   inflating: /content/dataset/uk20K_v2/168651-P.tif
#   inflating: /content/dataset/uk20K_v2/73880-P.tif
#   inflating: /content/dataset/uk20K_v2/519042-N.tif
#   inflating: /content/dataset/uk20K_v2/26572-P.tif
#   inflating: /content/dataset/uk20K_v2/64661-N.tif
#   inflating: /content/dataset/uk20K_v2/109599-P.tif
#   inflating: /content/dataset/uk20K_v2/175924-P.tif
#   inflating: /content/dataset/uk20K_v2/22977-P.tif
#   inflating: /content/dataset/uk20K_v2/25608-N.tif
#   inflating: /content/dataset/uk20K_v2/42027-P.tif
#   inflating: /content/dataset/uk20K_v2/136618-P.tif
#   inflating: /content/dataset/uk20K_v2/159430-N.tif
#   inflating: /content/dataset/uk20K_v2/320877-N.tif
#   inflating: /content/dataset/uk20K_v2/73599-P.tif
#   inflating: /content/dataset/uk20K_v2/17986-P.tif
#   inflating: /content/dataset/uk20K_v2/148521-P.tif
#   inflating: /content/dataset/uk20K_v2/166978-P.tif
#   inflating: /content/dataset/uk20K_v2/76550-N.tif
#   inflating: /content/dataset/uk20K_v2/203895-N.tif
#   inflating: /content/dataset/uk20K_v2/36788-P.tif
#   inflating: /content/dataset/uk20K_v2/552245-N.tif
#   inflating: /content/dataset/uk20K_v2/72247-P.tif
#   inflating: /content/dataset/uk20K_v2/735462-N.tif
#   inflating: /content/dataset/uk20K_v2/177114-P.tif
#   inflating: /content/dataset/uk20K_v2/196759-N.tif
#   inflating: /content/dataset/uk20K_v2/63-P.tif
#   inflating: /content/dataset/uk20K_v2/596598-N.tif
#   inflating: /content/dataset/uk20K_v2/87991-P.tif
#   inflating: /content/dataset/uk20K_v2/16995-P.tif
#   inflating: /content/dataset/uk20K_v2/561308-N.tif
#   inflating: /content/dataset/uk20K_v2/106618-N.tif
#   inflating: /content/dataset/uk20K_v2/161351-P.tif
#   inflating: /content/dataset/uk20K_v2/399459-N.tif
#   inflating: /content/dataset/uk20K_v2/109694-P.tif
#   inflating: /content/dataset/uk20K_v2/159745-N.tif
#   inflating: /content/dataset/uk20K_v2/379574-N.tif
#   inflating: /content/dataset/uk20K_v2/696773-N.tif
#   inflating: /content/dataset/uk20K_v2/489974-N.tif
#   inflating: /content/dataset/uk20K_v2/129579-P.tif
#   inflating: /content/dataset/uk20K_v2/45122-P.tif
#   inflating: /content/dataset/uk20K_v2/141601-N.tif
#   inflating: /content/dataset/uk20K_v2/79743-N.tif
#   inflating: /content/dataset/uk20K_v2/38418-N.tif
#   inflating: /content/dataset/uk20K_v2/657688-N.tif
#   inflating: /content/dataset/uk20K_v2/114846-P.tif
#   inflating: /content/dataset/uk20K_v2/42572-P.tif
#   inflating: /content/dataset/uk20K_v2/528869-N.tif
#   inflating: /content/dataset/uk20K_v2/45554-P.tif
#   inflating: /content/dataset/uk20K_v2/99573-N.tif
#   inflating: /content/dataset/uk20K_v2/541426-N.tif
#   inflating: /content/dataset/uk20K_v2/134180-P.tif
#   inflating: /content/dataset/uk20K_v2/33549-P.tif
#   inflating: /content/dataset/uk20K_v2/80351-P.tif
#   inflating: /content/dataset/uk20K_v2/473630-N.tif
#   inflating: /content/dataset/uk20K_v2/483085-N.tif
#   inflating: /content/dataset/uk20K_v2/315941-N.tif
#   inflating: /content/dataset/uk20K_v2/434433-N.tif
#   inflating: /content/dataset/uk20K_v2/156758-P.tif
#   inflating: /content/dataset/uk20K_v2/114898-P.tif
#   inflating: /content/dataset/uk20K_v2/78130-P.tif
#   inflating: /content/dataset/uk20K_v2/651401-N.tif
#   inflating: /content/dataset/uk20K_v2/25188-P.tif
#   inflating: /content/dataset/uk20K_v2/71190-P.tif
#   inflating: /content/dataset/uk20K_v2/174244-N.tif
#   inflating: /content/dataset/uk20K_v2/87119-P.tif
#   inflating: /content/dataset/uk20K_v2/145596-P.tif
#   inflating: /content/dataset/uk20K_v2/433873-N.tif
#   inflating: /content/dataset/uk20K_v2/545149-N.tif
#   inflating: /content/dataset/uk20K_v2/62951-N.tif
#   inflating: /content/dataset/uk20K_v2/89630-N.tif
#   inflating: /content/dataset/uk20K_v2/100831-P.tif
#   inflating: /content/dataset/uk20K_v2/670732-N.tif
#   inflating: /content/dataset/uk20K_v2/504169-N.tif
#   inflating: /content/dataset/uk20K_v2/331843-N.tif
#   inflating: /content/dataset/uk20K_v2/50833-P.tif
#   inflating: /content/dataset/uk20K_v2/79135-P.tif
#   inflating: /content/dataset/uk20K_v2/120474-P.tif
#   inflating: /content/dataset/uk20K_v2/313832-N.tif
#   inflating: /content/dataset/uk20K_v2/105963-N.tif
#   inflating: /content/dataset/uk20K_v2/106303-P.tif
#   inflating: /content/dataset/uk20K_v2/148938-N.tif
#   inflating: /content/dataset/uk20K_v2/103597-P.tif
#   inflating: /content/dataset/uk20K_v2/116752-P.tif
#   inflating: /content/dataset/uk20K_v2/103561-P.tif
#   inflating: /content/dataset/uk20K_v2/27308-P.tif
#   inflating: /content/dataset/uk20K_v2/54499-P.tif
#   inflating: /content/dataset/uk20K_v2/91127-N.tif
#   inflating: /content/dataset/uk20K_v2/684427-N.tif
#   inflating: /content/dataset/uk20K_v2/649097-N.tif
#   inflating: /content/dataset/uk20K_v2/72955-N.tif
#   inflating: /content/dataset/uk20K_v2/133304-P.tif
#   inflating: /content/dataset/uk20K_v2/157875-N.tif
#   inflating: /content/dataset/uk20K_v2/44792-P.tif
#   inflating: /content/dataset/uk20K_v2/406154-N.tif
#   inflating: /content/dataset/uk20K_v2/513303-N.tif
#   inflating: /content/dataset/uk20K_v2/60142-P.tif
#   inflating: /content/dataset/uk20K_v2/43818-P.tif
#   inflating: /content/dataset/uk20K_v2/16051-P.tif
#   inflating: /content/dataset/uk20K_v2/646959-N.tif
#   inflating: /content/dataset/uk20K_v2/114925-P.tif
#   inflating: /content/dataset/uk20K_v2/139603-P.tif
#   inflating: /content/dataset/uk20K_v2/594623-N.tif
#   inflating: /content/dataset/uk20K_v2/157580-P.tif
#   inflating: /content/dataset/uk20K_v2/492339-N.tif
#   inflating: /content/dataset/uk20K_v2/20151-N.tif
#   inflating: /content/dataset/uk20K_v2/1547-P.tif
#   inflating: /content/dataset/uk20K_v2/733292-N.tif
#   inflating: /content/dataset/uk20K_v2/124796-P.tif
#   inflating: /content/dataset/uk20K_v2/149392-P.tif
#   inflating: /content/dataset/uk20K_v2/167687-P.tif
#   inflating: /content/dataset/uk20K_v2/130911-P.tif
#   inflating: /content/dataset/uk20K_v2/302281-N.tif
#   inflating: /content/dataset/uk20K_v2/424893-N.tif
#   inflating: /content/dataset/uk20K_v2/42137-P.tif
#   inflating: /content/dataset/uk20K_v2/40707-N.tif

# %% [markdown]
# Let's prepare the train and validation datasets.

# %%
def normalize(image, MEAN = [0.485, 0.456, 0.406], STD = [0.485, 0.456, 0.406]):
    image = image / 255
    source, dest = 0 if len(image.shape) == 3 else 1, -1
    return np.moveaxis((np.moveaxis(image, source, dest) - MEAN) / STD, dest, source)

def denormalize(image, MEAN = [0.485, 0.456, 0.406], STD = [0.485, 0.456, 0.406]):
    source, dest = 0 if len(image.shape) == 3 else 1, -1
    image = np.moveaxis((np.moveaxis(image, source, dest) * STD) + MEAN, dest, source)
    return (image * 255).astype(int)


class SolarDataset(Dataset):
    def __init__(self, file_names):
        self.file_names = file_names

    def __len__(self):
        return len(self.file_names)

    def __getitem__(self, index):
        path = self.file_names[index]
        x = rasterio.open(self.file_names[index]).read()
        y = torch.tensor(1.0).long() if path.endswith('-P.tif') else torch.tensor(0.0).long()
        x = normalize(x, MEAN=[0.5, 0.5, 0.5], STD=[0.5, 0.5, 0.5])
        return torch.as_tensor(x.copy()).float(), y, self.file_names[index]

# %% [markdown]
# The dataset comprises of .tif image files. The images are labeled based on the presence or absence of solar panels within them. If an image's filename ends with "-P" it indicates a positive label, signifying that the image contains at least one solar panel. Conversely, if the filename ends with "-N" it denotes a negative label, implying that no solar panels are present in the image. However, the dataset does not provide any details regarding the size of the solar panels in the images.
#
# Split the dataset into train and test sets and create the dataloaders.

# %%
# ======================= Your Code =======================
def get_file_labels(file_names):
    labeled_files = []
    for file in file_names:
        if file.endswith('-P.tif'):
            labeled_files.append((file, 1))
        elif file.endswith('-N.tif'):
            labeled_files.append((file, 0))
    return labeled_files


file_names = [os.path.join('/content/dataset/uk20K_v2', f) for f in os.listdir('/content/dataset/uk20K_v2') if f.endswith('.tif')]
ds = SolarDataset(file_names)
# ======================= Your Code =======================

# %%
# ======================= Your Code =======================
batch_size = 32
train_size = int(0.8 * len(ds))
test_size = len(ds) - train_size
train_dataset, test_dataset = random_split(ds, [train_size, test_size])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# ======================= Your Code =======================

print(len(train_dataloader), len(test_dataloader))
# Out:
# 500 125

# %% [markdown]
# # Model definition

# %% [markdown]
# This section focuses on defining the models. The first component is a DINO backbone, which serves as a feature extractor. The code for DINO is already written and does not require any modifications. The second component is a classifier head that will be placed on top of the DINO features. The init function for this model has been provided, and your task is to complete the forward method.

# %%
class DinoBackbone(nn.Module):
    def __init__(self, dino_size='small') -> None:
        super().__init__()
        if dino_size == 'small':
            self.dinov2 = torch.hub.load('facebookresearch/dinov2', 'dinov2_vits14_reg')
            self.d_model = 384
        elif dino_size == 'base':
            self.dinov2 = torch.hub.load('facebookresearch/dinov2', 'dinov2_vitb14_reg')
            self.d_model = 768
        elif dino_size == 'giant':
            self.dinov2 = torch.hub.load('facebookresearch/dinov2', 'dinov2_vitg14_reg')
            self.d_model = 1536

    def forward(self, x):
        x = self.dinov2.forward_features(x)
        cls_token = x["x_norm_clstoken"]
        patch_tokens = x["x_norm_patchtokens"]
        return cls_token, patch_tokens

# %%
class TransformerEncoderLinearHead(nn.Module):

    def __init__(self, d_model, output_size) -> None:
        super().__init__()
        self.transformer = nn.TransformerEncoderLayer(d_model, 8, batch_first=True)
        self.fc = nn.Linear(d_model, 2)

    def forward(self, x_feats):
        cls_embs, patch_embs = x_feats

        # ==================== Your Code ====================
        # 1. Pass the cls and patch embeddings as a single sequence to the transformer layer
        embeddings = torch.cat((cls_embs.unsqueeze(1), patch_embs), dim=1)
        transformer_output = self.transformer(embeddings)

        # 2. Pass the cls output of the transformer to the linear model
        cls_output = transformer_output[:, 0, :]

        # 3. Return the output of the linear model as the prediction
        output = self.fc(cls_output)
        return output
        # ==================== Your Code ====================

    def get_size_estimate(self, x_feats, threshold, vis=False, images=None):
        cls_embs, patch_embs = x_feats

        # ==================== Your Code ====================
        # Note: This function is used in the second part of the notebook for size estimation.
        # 1. Pass cls and patch embeddings to the self-attention layer of the transformer defined in the init.
        #           use "self.transformer.self_attn()"
        embeddings = torch.cat((cls_embs.unsqueeze(1), patch_embs), dim=1)
        transformer_output = self.transformer.self_attn(embeddings, embeddings, embeddings, need_weights=True, average_attn_weights=False)

        # 2. When using the self_attn layer make sure to set the need_weights=True. (This will give you the attention scores)
        attn_weights = transformer_output[1]

        # 3. The previous step computes the attention of each token with all other tokens. (shape: hx257x257 where h is the number of heads)
        # 4. Get the attention score of cls token with all patch tokens (shape: hx256)
        cls_attn_scores = attn_weights[:, :, 0, 1:]

        # 5. Reshape this into hx16x16.
        h = int(np.sqrt(cls_attn_scores.shape[-1]))
        cls_attn_scores = cls_attn_scores.view(cls_attn_scores.size(0), cls_attn_scores.size(1), h, h)

        # 6. Upsample this 16x16 image by a factor of 14. (You get a hx224x224 image)
        # 7. Sum accross the heads (shape: 224x224)
        cls_attn_scores = cls_attn_scores.repeat_interleave(14, dim=2).repeat_interleave(14, dim=3)
        attention = cls_attn_scores.sum(dim=1)

        # 8. Normalize this 224x224 into the [0,1] range for all pixels.
        attention = (attention - torch.min(attention))/(torch.max(attention)-torch.min(attention))

        # 9. Create a binary mask from this 224x224 using a threshold (You should choose this threshold.)
        # 10. This mask is an estimation of the solar panels in the image (if it exists). You can use it to estimate the size of the solar panel.
        attention = (attention>threshold).cpu() * 1.0
        # 11. Good Luck.
        # ==================== Your Code ====================

        h, w = attention.shape[-2:]
        visualization_images = []
        if vis:
            for i in range(images.shape[0]):
                img = images[i].detach().cpu().numpy().transpose((1, 2, 0))
                normalized_img = Normalize(vmin=img.min(), vmax=img.max())(img)

                reds = plt.cm.Reds(attention[i])
                alpha_max_value = 1.00
                gamma = 0.5

                rgba_img = np.zeros((h, w, 4))
                rgba_img[..., :3] = normalized_img
                rgba_img[..., 3] = 1

                rgba_mask = np.zeros((h, w, 4))
                rgba_mask[..., :3] = reds[..., :3]
                rgba_mask[..., 3] = np.power(attention[i], gamma) * alpha_max_value

                rgba_all = np.zeros((h, 2*w, 4))
                rgba_all[:, :w, :] = rgba_img
                rgba_all[:, w:, :] = rgba_mask

                visualization_images.append(rgba_all)

        counts = attention.sum((1, 2))
        return counts, visualization_images

# %% [markdown]
# # Train

# %% [markdown]
# Now initialize the model, define the optimizer and loss function and train the classifier model. Train your model for 2 epochs (this should be pretty fast). Pay attention that your code produces similar output as the one in the notebook so that training loss and validation accuracy are reported.

# %%
device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')

backbone = DinoBackbone(dino_size='small')
backbone = backbone.to(device)
backbone.eval()
head = TransformerEncoderLinearHead(backbone.d_model, 2)
head = head.to(device)
# Out:
# Downloading: "https://github.com/facebookresearch/dinov2/zipball/main" to /root/.cache/torch/hub/main.zip
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# Downloading: "https://dl.fbaipublicfiles.com/dinov2/dinov2_vits14/dinov2_vits14_reg4_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dinov2_vits14_reg4_pretrain.pth
# 100%|██████████| 84.2M/84.2M [00:00<00:00, 178MB/s]

# %%
lr = 0.001
optimizer = torch.optim.Adam(head.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()

# %%
iter = 0
running_loss = 0

for epoch in range(1):

# ==================== Your Code ====================
# Write the training loop
# Be careful: in each iteration you first have to extract the DINO features and
# the pass the features to your classifier network,
# pay attention that you must freeze the DINO weights so that it isn't trained. (Use torch.no_grads() block.)
    for images, labels, _ in train_dataloader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()

        with torch.no_grad():
            features = backbone(images)

        outputs = head(features)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        iter += 1

        if iter % 10 == 0:
            print(f"Iteration {iter}, Loss: {running_loss / 10}")
            running_loss = 0
# ==================== Your Code ====================

torch.save(head.state_dict(), 'final_model.pth')
# Out:
# Iteration 10, Loss: 0.9057200163602829
# Iteration 20, Loss: 0.34212832152843475
# Iteration 30, Loss: 0.3003771036863327
# Iteration 40, Loss: 0.3141984403133392
# Iteration 50, Loss: 0.29001026675105096
# Iteration 60, Loss: 0.21845827102661133
# Iteration 70, Loss: 0.2335050366818905
# Iteration 80, Loss: 0.18929304778575898
# Iteration 90, Loss: 0.19426880441606045
# Iteration 100, Loss: 0.25567961037158965
# Iteration 110, Loss: 0.19553604647517203
# Iteration 120, Loss: 0.22811594009399414
# Iteration 130, Loss: 0.19247329533100127
# Iteration 140, Loss: 0.2096800610423088
# Iteration 150, Loss: 0.21651556789875032
# Iteration 160, Loss: 0.20688668489456177
# Iteration 170, Loss: 0.20591503232717515
# Iteration 180, Loss: 0.23124735206365585
# Iteration 190, Loss: 0.21024942249059678
# Iteration 200, Loss: 0.25821307152509687
# Iteration 210, Loss: 0.26672503054142
# Iteration 220, Loss: 0.2611685186624527
# Iteration 230, Loss: 0.16248217448592187
# Iteration 240, Loss: 0.2119712181389332
# Iteration 250, Loss: 0.1628285836428404
# Iteration 260, Loss: 0.18408765606582164
# Iteration 270, Loss: 0.21962431073188782
# Iteration 280, Loss: 0.17700749561190604
# Iteration 290, Loss: 0.17511523738503457
# Iteration 300, Loss: 0.20965132638812065
# Iteration 310, Loss: 0.1721147172152996
# Iteration 320, Loss: 0.2403457522392273
# Iteration 330, Loss: 0.18151641264557838
# Iteration 340, Loss: 0.1735382579267025
# Iteration 350, Loss: 0.18229171857237816
# Iteration 360, Loss: 0.1790621630847454
# Iteration 370, Loss: 0.1421555306762457
# Iteration 380, Loss: 0.22215975746512412
# Iteration 390, Loss: 0.2423502892255783
# Iteration 400, Loss: 0.2087801955640316
# Iteration 410, Loss: 0.18871862217783927
# Iteration 420, Loss: 0.21085984222590923
# Iteration 430, Loss: 0.1735446035861969
# Iteration 440, Loss: 0.25197489447891713
# Iteration 450, Loss: 0.19787173345685005
# Iteration 460, Loss: 0.2189536139369011
# Iteration 470, Loss: 0.19262723699212075
# Iteration 480, Loss: 0.14423975087702273
# Iteration 490, Loss: 0.24042672291398048
# Iteration 500, Loss: 0.20400766879320145

# %%
device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')

backbone = DinoBackbone(dino_size='small')
backbone = backbone.to(device)
backbone.eval()
head = TransformerEncoderLinearHead(backbone.d_model, 2)
head.load_state_dict(torch.load('final_model.pth'))
head = head.to(device)
# Out:
# Using cache found in /root/.cache/torch/hub/facebookresearch_dinov2_main

# %% [markdown]
# Now go through the validation set and for every image predict whether it contains solar panel or not. Then from all the images that contain solar panels, visualize some that have the large panels and some with the small panels based on your size estimation module. Your outputs should be something like the following. Remeber: you have to look at size estimates only for images that are predicted positive (contain solar panel.) The size estimation module doesn't work for negative images (There are no panels to estimate their size).

# %%
"""
in this cell I want to my output be as same as your output so hyperparameters set to these:
  threshold = 0.2
  count limit = 4
"""
multi_panels = []
one_panel = []
panel_size = 196.0
count_limit = 4
threshold = 0.2

with torch.no_grad():
    for inputs, labels, _ in test_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        dino_features = backbone(inputs)
        outputs = head(dino_features)
        predicted = torch.max(outputs.data, 1)[1]
        total += labels.size(0)
        count, img = head.get_size_estimate(dino_features, threshold, vis=True, images=inputs)

        for i in range(len(img)):
            if predicted[i] == 1 and panel_size - 1 < count[i] < panel_size + 1 and len(one_panel) < 4:
                one_panel.append((count[i], img[i]))
            elif predicted[i] == 1 and count[i] > panel_size * count_limit and len(multi_panels) < 4:
                multi_panels.append((count[i], img[i]))
        if len(one_panel) >= 3 and len(multi_panels) >= 3:
            break

print("Plotting the multi panels:")
for count, img in multi_panels:
    print(f"Size estimate: {count.item()}")
    plt.imshow(img)
    plt.show()

print("Plotting the one panels:")
for count, img in one_panel:
    print(f"Size estimate: {count.item()}")
    plt.imshow(img)
    plt.show()
# Out:
# Plotting the multi panels:
# Size estimate: 980.0
# Size estimate: 980.0
# Size estimate: 1176.0
# Size estimate: 1176.0
# Plotting the one panels:
# Size estimate: 196.0
# Size estimate: 196.0
# Size estimate: 196.0

# %%
"""
in this cell I want to my output be as accurate as it can be so I set the hyperparameters to these:
  threshold = 0.6
  count limit = 5
"""
multi_panels = []
one_panel = []
panel_size = 196.0
count_limit = 5
threshold = 0.6

with torch.no_grad():
    for inputs, labels, _ in test_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        dino_features = backbone(inputs)
        outputs = head(dino_features)
        predicted = torch.max(outputs.data, 1)[1]
        total += labels.size(0)
        count, img = head.get_size_estimate(dino_features, threshold, vis=True, images=inputs)

        for i in range(len(img)):
            if predicted[i] == 1 and panel_size - 1 < count[i] < panel_size + 1 and len(one_panel) < 4:
                one_panel.append((count[i], img[i]))
            elif predicted[i] == 1 and count[i] > panel_size * count_limit and len(multi_panels) < 4:
                multi_panels.append((count[i], img[i]))
        if len(one_panel) >= 3 and len(multi_panels) >= 3:
            break

print("Plotting the multi panels:")
for count, img in multi_panels:
    print(f"Size estimate: {count.item()}")
    plt.imshow(img)
    plt.show()

print("Plotting the one panels:")
for count, img in one_panel:
    print(f"Size estimate: {count.item()}")
    plt.imshow(img)
    plt.show()
# Out:
# Plotting the multi panels:
# Plotting the one panels:
# Size estimate: 196.0
# Size estimate: 196.0
# Size estimate: 196.0
# Size estimate: 196.0
